# %% [markdown]
#  This project analyzes data on the current population, population growth rate, and world percentage of the top 10 most densely populated countries in the world. The dataset was collected from Kaggle and includes information such as the country name, current population, projected population for 2022, area, land area, density, growth rate, world percentage, and rank. Using Python and various data visualization libraries, we explore the data to determine which countries are the most densely populated and which countries have the highest population growth rates and world percentages. Through this analysis, we gain insights into the current state and trends of global population growth.

# %% [markdown]
# ## Step 1: Import the Required Libraries
# To start with, let's import the required libraries that we'll need for the project. We'll be using pandas to read the CSV file and to manipulate the data, and numpy and matplotlib for data analysis and visualization.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 2: Load the Excel File
# Next, let's load the Excel file that contains the world population data. We have downloaded the CSV file from a reliable source such as kaggle free dataset available.

# %%
world_population_data = pd.read_excel('/Users/rising.volkan007/Desktop/World_population_analysis/world_population2023.xlsx')

# %% [markdown]
# ## Step 3: Data Exploration and Cleaning
# Before we start the statistical analysis, let's explore the data and clean it if necessary. We can check the first few rows of the dataset using the head() method to make sure that the data is loaded correctly.

# %%
world_population_data.head()
# Out:
#    Unnamed: 0   country name current population population 2022    area  \
# 0           0          India      1,423,118,510   1,417,173,173    3.3M
# 1           1          China      1,425,820,141   1,425,887,337    9.7M
# 2           2  United States        339,231,549     338,289,857    9.4M
# 3           3      Indonesia        276,576,867     275,501,339    1.9M
# 4           4       Pakistan        238,517,163     235,824,862  881.9K
#
#   land area  density growth rate world percentage  rank
# 0        3M      481       0.81%           17.85%     1
# 1      9.4M      151      -0.02%           17.81%     2
# 2      9.1M       37       0.50%            4.25%     3
# 3      1.9M      148       0.74%            3.47%     4
# 4    770.9K      312       1.98%            3.00%     5

# %% [markdown]
# #### we need to remove commas from the two columns 'current population' and 'population 2022' and then make it to read these as float types for our analysis.

# %%
world_population_data['current population'] = world_population_data['current population'].str.replace(',', '').astype(float)
world_population_data['population 2022'] = world_population_data['population 2022'].str.replace(',', '').astype(float)

# %% [markdown]
# We can also check the size of the dataset using the shape attribute.

# %%
world_population_data.head()
# Out:
#    Unnamed: 0   country name  current population  population 2022    area  \
# 0           0          India        1.423119e+09     1.417173e+09    3.3M
# 1           1          China        1.425820e+09     1.425887e+09    9.7M
# 2           2  United States        3.392315e+08     3.382899e+08    9.4M
# 3           3      Indonesia        2.765769e+08     2.755013e+08    1.9M
# 4           4       Pakistan        2.385172e+08     2.358249e+08  881.9K
#
#   land area  density growth rate world percentage  rank
# 0        3M      481       0.81%           17.85%     1
# 1      9.4M      151      -0.02%           17.81%     2
# 2      9.1M       37       0.50%            4.25%     3
# 3      1.9M      148       0.74%            3.47%     4
# 4    770.9K      312       1.98%            3.00%     5

# %%
world_population_data.shape
# Out:
# (205, 10)

# %%
world_population_data.columns
# Out:
# Index(['Unnamed: 0', 'country name', 'current population', 'population 2022',
#        'area', 'land area', 'density', 'growth rate', 'world percentage',
#        'rank'],
#       dtype='object')

# %%
world_population_data.dtypes
# Out:
# Unnamed: 0              int64
# country name           object
# current population    float64
# population 2022       float64
# area                   object
# land area              object
# density                 int64
# growth rate            object
# world percentage       object
# rank                    int64
# dtype: object

# %% [markdown]
# #### we can use the pd.to_numeric() function to convert the 'current population' and 'population 2022' columns to float data types for further analysis process.

# %%
world_population_data['current population'] = pd.to_numeric(world_population_data['current population'], errors='coerce')
world_population_data['population 2022'] = pd.to_numeric(world_population_data['population 2022'], errors='coerce')

# %% [markdown]
#  #### Now we can check the data types of all columns again to confirm that the 'current population' and 'population 2022' columns are now of float data type.

# %%
print(world_population_data.dtypes)
# Out:
# Unnamed: 0              int64
# country name           object
# current population    float64
# population 2022       float64
# area                   object
# land area              object
# density                 int64
# growth rate            object
# world percentage       object
# rank                    int64
# dtype: object

# %% [markdown]
# We can use the describe() method to get some basic statistics of the data.

# %%
world_population_data.describe()
# Out:
#        Unnamed: 0  current population  population 2022       density  \
# count  205.000000        2.050000e+02     2.050000e+02    205.000000
# mean   102.000000        3.907452e+07     3.888173e+07    344.063415
# std     59.322565        1.458696e+08     1.455222e+08   1482.714281
# min      0.000000        5.180000e+02     5.100000e+02      1.000000
# 25%     51.000000        1.480242e+06     1.472233e+06     35.000000
# 50%    102.000000        7.590327e+06     7.529475e+06     95.000000
# 75%    153.000000        2.857019e+07     2.816054e+07    235.000000
# max    204.000000        1.425820e+09     1.425887e+09  18149.000000
#
#              rank
# count  205.000000
# mean   104.351220
# std     61.585136
# min      1.000000
# 25%     52.000000
# 50%    103.000000
# 75%    154.000000
# max    234.000000

# %% [markdown]
# If there are any missing values in the data, we can remove them using the dropna() method.

# %%
world_population_data.dropna(inplace=True)

# %%
# Count the number of missing values in each column
world_population_data.isnull().sum()
# Out:
# Unnamed: 0            0
# country name          0
# current population    0
# population 2022       0
# area                  0
# land area             0
# density               0
# growth rate           0
# world percentage      0
# rank                  0
# dtype: int64

# %% [markdown]
# ## Step 4: Statistical Analysis and Visualization
# Now that the data is cleaned, let's do some statistical analysis on the data. We can calculate the mean, median, and mode of the world population for current(2023) and population of 2022.

# %%
mean_population = np.mean(world_population_data['current population'])
median_population = np.median(world_population_data['current population'])
mode_population = world_population_data['current population'].mode()[0]

print('Mean Population:', mean_population)
print('Median Population:', median_population)
print('Mode Population:', mode_population)
# Out:
# Mean Population: 39266059.38235294
# Median Population: 8151866.5
# Mode Population: 11396.0

# %%
mean_pop_2022 = np.mean(world_population_data['population 2022'])
median_pop_2022 = np.median(world_population_data['population 2022'])
mode_pop_2022 = world_population_data['population 2022'].mode()[0]

print('Mean Population 2022:', mean_pop_2022)
print('Median Population 2022:', median_pop_2022)
print('Mode Population 2022:', mode_pop_2022)
# Out:
# Mean Population 2022: 39072328.52941176
# Median Population 2022: 8067596.5
# Mode Population 2022: 11312.0

# %% [markdown]
# #### Comparing the mean, median, and mode of the current population and population in 2022, we can see that the values for the mean, median, and mode are all higher for the current population compared to the population in 2022. This suggests that the world population is currently larger than what is projected for 2022. Additionally, the standard deviation of the current population is larger than that of the population in 2022, indicating that there is a wider range of population sizes among countries at present than what is expected for 2022. These insights can be useful in studying population trends and making projections for the future.

# %% [markdown]
# ## Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

# Create scatterplot
sns.scatterplot(x="rank", y="current population", data=world_population_data)

# Set title and labels
plt.title("Population vs Rank")
plt.xlabel("Rank")
plt.ylabel("Population")

# Show plot
plt.show()

# %% [markdown]
# This code creates a scatterplot with rank on the x-axis and population on the y-axis, using the sns.scatterplot function from Seaborn. We also set the title and axis labels using plt.title, plt.xlabel, and plt.ylabel. Finally, we use plt.show to display the plot.

# %%
# Sort data by population
sorted_data = world_population_data.sort_values("current population", ascending=False)

# Create bar chart
sns.barplot(x="current population", y="country name", data=sorted_data.head(10))

# Set title and labels
plt.title("Top 10 Countries by Population")
plt.xlabel("Population")
plt.ylabel("Country")

# Show plot
plt.show()

# %% [markdown]
# This code first sorts the data by population in descending order using sort_values, then creates a bar chart of the top 10 countries using sns.barplot. We also set the title and labels using plt.title, plt.xlabel, and plt.ylabel. Finally, we use plt.show to display the plot.

# %%
import matplotlib.pyplot as plt

# create figure and axes
fig, ax = plt.subplots(figsize=(20, 10))

# create scatter plot
ax.scatter(world_population_data['area'], world_population_data['current population'])

# add labels for each country
for i in range(len(world_population_data)):
    ax.annotate(world_population_data['country name'][i], (world_population_data['area'][i], world_population_data['current population'][i]), fontsize=16)

# set axis labels and title
ax.set_xlabel('Area (sq. km)', fontsize=12)
ax.set_ylabel('Population', fontsize=12)
ax.set_title('Population vs. Area', fontsize=14)

# display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# create histogram with 50 bins
plt.hist(world_population_data['density'], bins=10)

# set axis labels and title
plt.xlabel('Population Density')
plt.ylabel('Frequency')
plt.title('Distribution of Population Density')

# display the plot
plt.show()

# %%
# create a new dataframe sorted by population density in descending order
world_population_density = world_population_data.sort_values('density', ascending=False)

# top 10 densely populated countries
top_10_dense = world_population_density.head(10)

# plot bar graph
plt.figure(figsize=(10, 6))
plt.bar(top_10_dense['country name'], top_10_dense['density'])
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population Density')
plt.title('Top 10 Densely Populated Countries')
plt.show()

# %%
# create a new dataframe sorted by population density in ascending order
world_population_density = world_population_data.sort_values('density', ascending=True)

# top 10 least densely populated countries
top_10_least_dense = world_population_density.head(10)

# plot bar graph
plt.figure(figsize=(10, 6))
plt.bar(top_10_least_dense['country name'], top_10_least_dense['density'])
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population Density')
plt.title('Top 10 Least Densely Populated Countries')
plt.show()

# %% [markdown]
# ###   Between the two graphs above, Monaco is indeed the most densely populated country, while Greenland has the least population density. Bangladesh 7th and Singapore 2nd are both highly populated countries and have high population densities as well. It's interesting to see the variations in population density across different countries.

# %%
# remove % sign from "world percentage" column and convert to float
world_population_data['world percentage'] = world_population_data['world percentage'].str.rstrip('%').astype(float)

# sort dataframe by "world percentage" in descending order
world_population_percentage = world_population_data.sort_values('world percentage', ascending=False)

# create bar plot of top 3 countries by world percentage
top_3_world_percentage = world_population_percentage.head(3)
plt.bar(top_3_world_percentage['country name'], top_3_world_percentage['world percentage'])
plt.xlabel('Country')
plt.ylabel('World Population Percentage')
plt.title('Top 3 Countries by World Population Percentage')
plt.show()

# %%
# sort the dataframe by population density in descending order
world_population_density = world_population_data.sort_values('density', ascending=False)

# add a 'rank' column to the dataframe based on population density
world_population_density['rank'] = world_population_density['density'].rank(method='dense', ascending=False)

# select the top 10 countries by population density
top_10_dense = world_population_density.head(10)

# display the top 10 countries with their rank and population density
print(top_10_dense[['rank', 'country name', 'density']])
# Out:
#      rank country name  density
# 199   1.0       Monaco    18149
# 113   2.0    Singapore     8377
# 103   3.0    Hong Kong     7135
# 153   4.0      Bahrain     1892
# 172   5.0     Maldives     1737
# 171   6.0        Malta     1672
# 7     7.0   Bangladesh     1329
# 179   8.0      Mayotte      898
# 120   9.0    Palestine      892
# 56   10.0       Taiwan      661

# %%
top_10_population = world_population_data.sort_values('current population', ascending=False).head(10)

print(top_10_population)
# Out:
#    Unnamed: 0   country name  current population  population 2022    area  \
# 1           1          China        1.425820e+09     1.425887e+09    9.7M
# 0           0          India        1.423119e+09     1.417173e+09    3.3M
# 2           2  United States        3.392315e+08     3.382899e+08    9.4M
# 3           3      Indonesia        2.765769e+08     2.755013e+08    1.9M
# 4           4       Pakistan        2.385172e+08     2.358249e+08  881.9K
# 5           5        Nigeria        2.215925e+08     2.185412e+08  923.8K
# 6           6         Brazil        2.159050e+08     2.153135e+08    8.5M
# 7           7     Bangladesh        1.722209e+08     1.711864e+08  147.6K
# 8           8         Russia        1.446524e+08     1.447133e+08   17.1M
# 9           9         Mexico        1.280619e+08     1.275041e+08      2M
#
#   land area  density growth rate  world percentage  rank
# 1      9.4M      151      -0.02%             17.81     2
# 0        3M      481       0.81%             17.85     1
# 2      9.1M       37       0.50%              4.25     3
# 3      1.9M      148       0.74%              3.47     4
# 4    770.9K      312       1.98%              3.00     5
# 5    910.8K      246       2.41%              2.80     6
# 6      8.4M       26       0.52%              2.70     7
# 7    130.2K     1329       1.03%              2.16     8
# 8     16.4M        9      -0.19%              1.80     9
# 9      1.9M       66       0.75%              1.60    10

# %% [markdown]
# In terms of current population China is still ahead of India. But lets examine in terms of other aspects for final conclusion.

# %%
# We can try the following code to convert the 'growth rate' column to a float datatype:
# This code removes the percentage sign from the 'growth rate' column and converts it to a float datatype.

world_population_data['growth rate'] = world_population_data['growth rate'].str.rstrip('%').astype('float')/100

# %%
world_population_data.dtypes
# Out:
# Unnamed: 0              int64
# country name           object
# current population    float64
# population 2022       float64
# area                   object
# land area              object
# density                 int64
# growth rate           float64
# world percentage      float64
# rank                    int64
# dtype: object

# %%
# Sort the data by growth rate in descending order
df_sorted = world_population_data.sort_values(by=['growth rate'], ascending=False)

# Get the top 10 countries by growth rate
top_10_growth_rate = df_sorted.head(10)

# Rank the top 10 countries by growth rate
top_10_growth_rate['growth rate rank'] = top_10_growth_rate['growth rate'].rank(method='dense', ascending=False)

# Print the top 10 countries by growth rate and their ranks
print(top_10_growth_rate[['country name', 'growth rate', 'growth rate rank']])
# Out:
#     country name  growth rate  growth rate rank
# 133      Moldova       0.0498               1.0
# 59         Syria       0.0498               1.0
# 53         Niger       0.0380               2.0
# 14      Dr Congo       0.0329               3.0
# 66          Chad       0.0313               4.0
# 57          Mali       0.0310               5.0
# 68       Somalia       0.0310               5.0
# 41        Angola       0.0308               6.0
# 179      Mayotte       0.0303               7.0
# 21      Tanzania       0.0296               8.0
# /var/folders/3j/tlpxgbnn03s1zb0rcz4xx9j80000gn/T/ipykernel_989/1289767114.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10_growth_rate['growth rate rank'] = top_10_growth_rate['growth rate'].rank(method='dense', ascending=False)

# %% [markdown]
# We can see that Maldova and Syria jointly holds the highest growth rate.

# %%
# Sort the data by world percentage in descending order
df_sorted = world_population_data.sort_values(by=['world percentage'], ascending=False)

# Get the top 10 countries by world percentage
top_10_world_percentage = df_sorted.head(10)

# Rank the top 10 countries by world percentage
top_10_world_percentage['world percentage rank'] = top_10_world_percentage['world percentage'].rank(method='dense', ascending=False)

# Print the top 10 countries by world percentage and their ranks
print(top_10_world_percentage[['country name', 'world percentage', 'world percentage rank']])
# Out:
#     country name  world percentage  world percentage rank
# 0          India             17.85                    1.0
# 1          China             17.81                    2.0
# 2  United States              4.25                    3.0
# 3      Indonesia              3.47                    4.0
# 4       Pakistan              3.00                    5.0
# 5        Nigeria              2.80                    6.0
# 6         Brazil              2.70                    7.0
# 7     Bangladesh              2.16                    8.0
# 8         Russia              1.80                    9.0
# 9         Mexico              1.60                   10.0
# /var/folders/3j/tlpxgbnn03s1zb0rcz4xx9j80000gn/T/ipykernel_989/3064581037.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10_world_percentage['world percentage rank'] = top_10_world_percentage['world percentage'].rank(method='dense', ascending=False)

# %% [markdown]
# In terms of world's percentage India is higher which is a very important factor for ranking and which is why overall India is on the rank 1 list of current world population list.

# %% [markdown]
# #### Based on our analysis, we can conclude that Monaco is the most densely populated country, followed by Singapore and Hong Kong. In terms of growth rate, Moldova and Syria have the highest growth rates, followed by Niger and the Democratic Republic of the Congo. India has the largest world percentage, followed by China and the United States. Finally, the least densely populated country is Greenland.
#
# #### We can also see that India, China, and the United States rank highly in terms of world percentage, but India has the highest world percentage despite having a lower current population than China. Bangladesh also appears on both the growth rate and world percentage rankings, indicating its significant population growth.
#
# #### These findings provide insights into the current and projected populations of countries worldwide and highlight the varying population densities across countries.
